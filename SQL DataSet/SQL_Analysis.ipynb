# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("movies.csv")

# %%
df
# Out:
#                                    MOVIES         YEAR  \
# 0                           Blood Red Sky       (2021)
# 1     Masters of the Universe: Revelation     (2021– )
# 2                        The Walking Dead  (2010–2022)
# 3                          Rick and Morty     (2013– )
# 4                         Army of Thieves       (2021)
# ...                                   ...          ...
# 9994                       The Imperfects     (2021– )
# 9995                               Arcane     (2021– )
# 9996                    Heart of Invictus     (2022– )
# 9997                       The Imperfects     (2021– )
# 9998                       The Imperfects     (2021– )
#
#                                            GENRE  RATING  \
# 0         \nAction, Horror, Thriller                 6.1
# 1     \nAnimation, Action, Adventure                 5.0
# 2          \nDrama, Horror, Thriller                 8.2
# 3     \nAnimation, Adventure, Comedy                 9.2
# ...

# %%
df.isna().sum()
# Out:
# MOVIES         0
# YEAR         644
# GENRE         80
# RATING      1820
# ONE-LINE       0
# STARS          0
# VOTES       1820
# RunTime     2958
# Gross       9539
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.columns
# Out:
# Index(['MOVIES', 'YEAR', 'GENRE', 'RATING', 'ONE-LINE', 'STARS', 'VOTES',
#        'RunTime', 'Gross'],
#       dtype='object')

# %%
column={'MOVIES':'Movies', 'YEAR':'Year', 'GENRE':'Genre', 'RATING':'Rating', 'ONE-LINE':'One_Line', 'STARS':'Stars', 'VOTES':'Votes',
       'RunTime':'RunTime','Gross':'Gross'}

# %%
df=df.rename(columns=column)

# %%
df
# Out:
#                                                  Movies        Year  \
# 77                               The Hitman's Bodyguard      (2017)
# 85                                        Jurassic Park      (1993)
# 95                                        Don't Breathe      (2016)
# 111   The Lord of the Rings: The Fellowship of the Ring      (2001)
# 125                                         Escape Room  (I) (2019)
# ...                                                 ...         ...
# 5750                           Vidal Sassoon: The Movie      (2010)
# 5770                                       Men at Lunch      (2012)
# 5835                                    Decoding Deepak      (2012)
# 6056                                     Theo Who Lived      (2016)
# 6292                                   Southern Justice      (2006)
#
#                                           Genre  Rating  \
# 77          \nAction, Comedy, Crime                 6.9
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 460 entries, 77 to 6292
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Movies    460 non-null    object
#  1   Year      460 non-null    object
#  2   Genre     460 non-null    object
#  3   Rating    460 non-null    float64
#  4   One_Line  460 non-null    object
#  5   Stars     460 non-null    object
#  6   Votes     460 non-null    object
#  7   RunTime   460 non-null    float64
#  8   Gross     460 non-null    object
# dtypes: float64(2), object(7)
# memory usage: 35.9+ KB

# %%
df['Movies']=df['Movies'].str.replace('[Ãx][^A-Za-z]+','')
# Out:
# C:\Users\Ramakrishna\AppData\Local\Temp\ipykernel_5736\2881714741.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Movies']=df['Movies'].str.replace('[Ãx][^A-Za-z]+','')

# %%
df['Year']=df['Year'].str.replace('()[[Ãx][^A-Za-z]+','')
# Out:
# C:\Users\Ramakrishna\AppData\Local\Temp\ipykernel_5736\671252438.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Year']=df['Year'].str.replace('()[[Ãx][^A-Za-z]+','')

# %%
df['Genre']=df['Genre'].str.replace('\n','')

# %%
df
# Out:
#                                                  Movies        Year  \
# 77                               The Hitman's Bodyguard      (2017)
# 85                                        Jurassic Park      (1993)
# 95                                        Don't Breathe      (2016)
# 111   The Lord of the Rings: The Fellowship of the Ring      (2001)
# 125                                         Escape Room  (I) (2019)
# ...                                                 ...         ...
# 5750                           Vidal Sassoon: The Movie      (2010)
# 5770                                       Men at Lunch      (2012)
# 5835                                    Decoding Deepak      (2012)
# 6056                                     Theo Who Lived      (2016)
# 6292                                   Southern Justice      (2006)
#
#                                         Genre  Rating  \
# 77          Action, Comedy, Crime                 6.9
# ...

# %%
df['One_Line']=df['One_Line'].str.replace('\n','')

# %%
df
# Out:
#                                                  Movies        Year  \
# 77                               The Hitman's Bodyguard      (2017)
# 85                                        Jurassic Park      (1993)
# 95                                        Don't Breathe      (2016)
# 111   The Lord of the Rings: The Fellowship of the Ring      (2001)
# 125                                         Escape Room  (I) (2019)
# ...                                                 ...         ...
# 5750                           Vidal Sassoon: The Movie      (2010)
# 5770                                       Men at Lunch      (2012)
# 5835                                    Decoding Deepak      (2012)
# 6056                                     Theo Who Lived      (2016)
# 6292                                   Southern Justice      (2006)
#
#                                         Genre  Rating  \
# 77          Action, Comedy, Crime                 6.9
# ...

# %%
df['Stars']=df['Stars'].str.replace('\n','')

# %%
df
# Out:
#                                                  Movies        Year  \
# 77                               The Hitman's Bodyguard      (2017)
# 85                                        Jurassic Park      (1993)
# 95                                        Don't Breathe      (2016)
# 111   The Lord of the Rings: The Fellowship of the Ring      (2001)
# 125                                         Escape Room  (I) (2019)
# ...                                                 ...         ...
# 5750                           Vidal Sassoon: The Movie      (2010)
# 5770                                       Men at Lunch      (2012)
# 5835                                    Decoding Deepak      (2012)
# 6056                                     Theo Who Lived      (2016)
# 6292                                   Southern Justice      (2006)
#
#                                         Genre  Rating  \
# 77          Action, Comedy, Crime                 6.9
# ...

# %%
df['Gross']=df['Gross'].str.replace('$','')
# Out:
# C:\Users\Ramakrishna\AppData\Local\Temp\ipykernel_5736\2861824965.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['Gross']=df['Gross'].str.replace('$','')

# %%
df
# Out:
#                                                  Movies        Year  \
# 77                               The Hitman's Bodyguard      (2017)
# 85                                        Jurassic Park      (1993)
# 95                                        Don't Breathe      (2016)
# 111   The Lord of the Rings: The Fellowship of the Ring      (2001)
# 125                                         Escape Room  (I) (2019)
# ...                                                 ...         ...
# 5750                           Vidal Sassoon: The Movie      (2010)
# 5770                                       Men at Lunch      (2012)
# 5835                                    Decoding Deepak      (2012)
# 6056                                     Theo Who Lived      (2016)
# 6292                                   Southern Justice      (2006)
#
#                                         Genre  Rating  \
# 77          Action, Comedy, Crime                 6.9
# ...

# %%
df['Gross']=df['Gross'].str.replace('M','')

# %%
df['Year']=df['Year'].str.replace('(I)','')
# Out:
# C:\Users\Ramakrishna\AppData\Local\Temp\ipykernel_5736\206129135.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Year']=df['Year'].str.replace('(I)','')

# %%
df
# Out:
#                                                  Movies       Year  \
# 77                               The Hitman's Bodyguard     (2017)
# 85                                        Jurassic Park     (1993)
# 95                                        Don't Breathe     (2016)
# 111   The Lord of the Rings: The Fellowship of the Ring     (2001)
# 125                                         Escape Room  () (2019)
# ...                                                 ...        ...
# 5750                           Vidal Sassoon: The Movie     (2010)
# 5770                                       Men at Lunch     (2012)
# 5835                                    Decoding Deepak     (2012)
# 6056                                     Theo Who Lived     (2016)
# 6292                                   Southern Justice     (2006)
#
#                                         Genre  Rating  \
# 77          Action, Comedy, Crime                 6.9
# ...

# %%
df['Year']=df['Year'].str.replace('(','')
# Out:
# C:\Users\Ramakrishna\AppData\Local\Temp\ipykernel_5736\1807718984.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['Year']=df['Year'].str.replace('(','')

# %%
df['Year']=df['Year'].str.replace(')',' ')
# Out:
# C:\Users\Ramakrishna\AppData\Local\Temp\ipykernel_5736\2365644643.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['Year']=df['Year'].str.replace(')',' ')

# %%
df
# Out:
#                                                  Movies     Year  \
# 77                               The Hitman's Bodyguard    2017
# 85                                        Jurassic Park    1993
# 95                                        Don't Breathe    2016
# 111   The Lord of the Rings: The Fellowship of the Ring    2001
# 125                                         Escape Room    2019
# ...                                                 ...      ...
# 5750                           Vidal Sassoon: The Movie    2010
# 5770                                       Men at Lunch    2012
# 5835                                    Decoding Deepak    2012
# 6056                                     Theo Who Lived    2016
# 6292                                   Southern Justice    2006
#
#                                         Genre  Rating  \
# 77          Action, Comedy, Crime                 6.9
# 85      Action, Adventure, Sci-Fi                 8.1
# ...

# %%
df.to_csv('clean_movies.csv')
